# %% [markdown]
# # Alura
#
# Curso de introdução a data science na saúde da www.alura.com.br

# %%
import pandas as pd

confirmed = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv")
confirmed.head()
# Out:
#   Province/State  Country/Region      Lat  ...  3/2/20  3/3/20  3/4/20
# 0          Anhui  Mainland China  31.8257  ...     990     990     990
# 1        Beijing  Mainland China  40.1824  ...     414     414     418
# 2      Chongqing  Mainland China  30.0572  ...     576     576     576
# 3         Fujian  Mainland China  26.0789  ...     296     296     296
# 4          Gansu  Mainland China  36.0611  ...      91      91      91
#
# [5 rows x 47 columns]

# %%
confirmed.shape
# Out:
# (160, 47)

# %%
last_date = "3/2/20"

confirmed[last_date]
# Out:
# 0      990
# 1      414
# 2      576
# 3      296
# 4       91
#       ...
# 155      0
# 156      0
# 157      0
# 158      0
# 159      0
# Name: 3/2/20, Length: 160, dtype: int64

# %%
confirmed["Country/Region"]
# Out:
# 0      Mainland China
# 1      Mainland China
# 2      Mainland China
# 3      Mainland China
# 4      Mainland China
#             ...
# 155         Gibraltar
# 156     Liechtenstein
# 157            Poland
# 158           Tunisia
# 159                US
# Name: Country/Region, Length: 160, dtype: object

# %%
confirmed["Country/Region"].unique()
# Out:
# array(['Mainland China', 'Thailand', 'Japan', 'South Korea', 'Taiwan',
#        'US', 'Macau', 'Hong Kong', 'Singapore', 'Vietnam', 'France',
#        'Nepal', 'Malaysia', 'Canada', 'Australia', 'Cambodia',
#        'Sri Lanka', 'Germany', 'Finland', 'United Arab Emirates',
#        'Philippines', 'India', 'Italy', 'UK', 'Russia', 'Sweden', 'Spain',
#        'Belgium', 'Others', 'Egypt', 'Iran', 'Lebanon', 'Iraq', 'Oman',
#        'Afghanistan', 'Bahrain', 'Kuwait', 'Algeria', 'Croatia',
#        'Switzerland', 'Austria', 'Israel', 'Pakistan', 'Brazil',
#        'Georgia', 'Greece', 'North Macedonia', 'Norway', 'Romania',
#        'Denmark', 'Estonia', 'Netherlands', 'San Marino', 'Belarus',
#        'Iceland', 'Lithuania', 'Mexico', 'New Zealand', 'Nigeria',
#        'Ireland', 'Luxembourg', 'Monaco', 'Qatar', 'Ecuador',
#        'Azerbaijan', 'Czech Republic', 'Armenia', 'Dominican Republic',
#        'Indonesia', 'Portugal', 'Andorra', 'Latvia', 'Morocco',
#        'Saudi Arabia', 'Senegal', 'Argentina', 'Chile', 'Jordan',
#        'Ukraine', 'Saint Barthelemy', 'Hungary', 'Faroe Islands',
#        'Gibraltar', 'Liechtenstein', 'Poland', 'Tunisia'], dtype=object)

# %%
confirmed["Province/State"].unique()
# Out:
# array(['Anhui', 'Beijing', 'Chongqing', 'Fujian', 'Gansu', 'Guangdong',
#        'Guangxi', 'Guizhou', 'Hainan', 'Hebei', 'Heilongjiang', 'Henan',
#        'Hubei', 'Hunan', 'Inner Mongolia', 'Jiangsu', 'Jiangxi', 'Jilin',
#        'Liaoning', 'Ningxia', 'Qinghai', 'Shaanxi', 'Shandong',
#        'Shanghai', 'Shanxi', 'Sichuan', 'Tianjin', 'Tibet', 'Xinjiang',
#        'Yunnan', 'Zhejiang', nan, 'Taiwan', 'King County, WA',
#        'Cook County, IL', 'Tempe, AZ', 'Macau', 'Hong Kong',
#        'Toronto, ON', 'British Columbia', 'Los Angeles, CA',
#        'New South Wales', 'Victoria', 'Queensland', 'London, ON',
#        'Santa Clara, CA', 'South Australia', 'Boston, MA',
#        'San Benito, CA', 'Madison, WI', 'Diamond Princess cruise ship',
#        'San Diego County, CA', 'San Antonio, TX',
#        'Omaha, NE (From Diamond Princess)',
#        'Travis, CA (From Diamond Princess)', 'From Diamond Princess',
#        'Lackland, TX (From Diamond Princess)', 'Humboldt County, CA',
#        'Sacramento County, CA',
#        'Unassigned Location (From Diamond Princess)', ' Montreal, QC',
#        'Western Australia', 'Snohomish County, WA', 'Providence, RI',
#        'Tasmania', 'Grafton County, NH', 'Hillsborough, FL',
#        'New York City, NY', 'Placer County, CA', 'San Mateo, CA',
#        'Sarasota, FL', 'Sonoma County, CA', 'Umatilla, OR',
#        'Fulton County, GA', 'Washington County, OR',
#        ' Norfolk County, MA', 'Berkeley, CA', 'Maricopa County, AZ',
#        'Wake County, NC', 'Westchester County, NY', 'Orange County, CA',
#        'Northern Territory', 'Contra Costa County, CA'], dtype=object)

# %%
confirmed.sample(20)
# Out:
#               Province/State  Country/Region      Lat  ...  3/2/20  3/3/20  3/4/20
# 68                       NaN         Belgium  50.8333  ...       8      13      23
# 43                       NaN           Nepal  28.1667  ...       1       1       1
# 92                       NaN          Israel  31.0000  ...      10      12      15
# 47           Los Angeles, CA              US  34.0522  ...       1       1       7
# 73                       NaN           Egypt  26.0000  ...       2       2       2
# 22                  Shandong  Mainland China  36.3427  ...     758     758     758
# 127                      NaN          Latvia  56.8796  ...       1       1       1
# 79                       NaN         Lebanon  33.8547  ...      13      13      13
# 13                     Hunan  Mainland China  27.6104  ...    1018    1018    1018
# 45               Toronto, ON          Canada  43.6532  ...      17      19      19
# 113                      NaN      Luxembourg  49.8153  ...       1       1       1
# 18                  Liaoning  Mainland China  41.2956  ...     122     125     125
# 2                  Chongqing  Mainland China  30.0572  ...     576     576     576
# 81     Sacramento County, CA              US  38.4747  ...       2       2       2
# 159  Contra Costa County, CA              US  37.8534  ...       0       0       1
# 123                      NaN       Indonesia  -0.7893  ...       2       2       2
# 110                      NaN         Nigeria   9.0820  ...       1       1       1
# 72           San Antonio, TX              US  29.4241  ...       1       1       1
# 34                    Taiwan          Taiwan  23.7000  ...      41      42      42
# 21                   Shaanxi  Mainland China  35.1917  ...     245     245     245
#
# [20 rows x 47 columns]

# %%
confirmed.iloc[1]
# Out:
# Province/State           Beijing
# Country/Region    Mainland China
# Lat                      40.1824
# Long                     116.414
# 1/22/20                       14
# 1/23/20                       22
# 1/24/20                       36
# 1/25/20                       41
# 1/26/20                       68
# 1/27/20                       80
# 1/28/20                       91
# 1/29/20                      111
# 1/30/20                      114
# 1/31/20                      139
# 2/1/20                       168
# 2/2/20                       191
# 2/3/20                       212
# 2/4/20                       228
# 2/5/20                       253
# 2/6/20                       274
# 2/7/20                       297
# 2/8/20                       315
# 2/9/20                       326
# 2/10/20                      337
# 2/11/20                      342
# 2/12/20                      352
# 2/13/20                      366
# 2/14/20                      372
# 2/15/20                      375
# 2/16/20                      380
# 2/17/20                      381
# 2/18/20                      387
# 2/19/20                      393
# 2/20/20                      395
# 2/21/20                      396
# 2/22/20                      399
# 2/23/20                      399
# 2/24/20                      399
# 2/25/20                      400
# 2/26/20                      400
# 2/27/20                      410
# 2/28/20                      410
# 2/29/20                      411
# 3/1/20                       413
# 3/2/20                       414
# 3/3/20                       414
# 3/4/20                       418
# Name: 1, dtype: object

# %%
confirmed.set_index("Province/State").loc["Anhui"]
# Out:
# Country/Region    Mainland China
# Lat                      31.8257
# Long                     117.226
# 1/22/20                        1
# 1/23/20                        9
# 1/24/20                       15
# 1/25/20                       39
# 1/26/20                       60
# 1/27/20                       70
# 1/28/20                      106
# 1/29/20                      152
# 1/30/20                      200
# 1/31/20                      237
# 2/1/20                       297
# 2/2/20                       340
# 2/3/20                       408
# 2/4/20                       480
# 2/5/20                       530
# 2/6/20                       591
# 2/7/20                       665
# 2/8/20                       733
# 2/9/20                       779
# 2/10/20                      830
# 2/11/20                      860
# 2/12/20                      889
# 2/13/20                      910
# 2/14/20                      934
# 2/15/20                      950
# 2/16/20                      962
# 2/17/20                      973
# 2/18/20                      982
# 2/19/20                      986
# 2/20/20                      987
# 2/21/20                      988
# 2/22/20                      989
# 2/23/20                      989
# 2/24/20                      989
# 2/25/20                      989
# 2/26/20                      989
# 2/27/20                      989
# 2/28/20                      990
# 2/29/20                      990
# 3/1/20                       990
# 3/2/20                       990
# 3/3/20                       990
# 3/4/20                       990
# Name: Anhui, dtype: object

# %%
confirmed.set_index("Province/State").iloc[1]
# Out:
# Country/Region    Mainland China
# Lat                      40.1824
# Long                     116.414
# 1/22/20                       14
# 1/23/20                       22
# 1/24/20                       36
# 1/25/20                       41
# 1/26/20                       68
# 1/27/20                       80
# 1/28/20                       91
# 1/29/20                      111
# 1/30/20                      114
# 1/31/20                      139
# 2/1/20                       168
# 2/2/20                       191
# 2/3/20                       212
# 2/4/20                       228
# 2/5/20                       253
# 2/6/20                       274
# 2/7/20                       297
# 2/8/20                       315
# 2/9/20                       326
# 2/10/20                      337
# 2/11/20                      342
# 2/12/20                      352
# 2/13/20                      366
# 2/14/20                      372
# 2/15/20                      375
# 2/16/20                      380
# 2/17/20                      381
# 2/18/20                      387
# 2/19/20                      393
# 2/20/20                      395
# 2/21/20                      396
# 2/22/20                      399
# 2/23/20                      399
# 2/24/20                      399
# 2/25/20                      400
# 2/26/20                      400
# 2/27/20                      410
# 2/28/20                      410
# 2/29/20                      411
# 3/1/20                       413
# 3/2/20                       414
# 3/3/20                       414
# 3/4/20                       418
# Name: Beijing, dtype: object

# %%
# valor falso pois o erro é muito grande
# não vou considerar essa analise pois tem muito campo vazio (muita disparidade no padrão)

confirmed["Country/Region"].value_counts()
# Out:
# US                35
# Mainland China    31
# Australia          8
# Canada             4
# Kuwait             1
#                   ..
# Oman               1
# Morocco            1
# Latvia             1
# Belgium            1
# Jordan             1
# Name: Country/Region, Length: 86, dtype: int64

# %%
confirmed_by_country = confirmed.groupby("Country/Region").sum()
confirmed_by_country.head()
# Out:
#                     Lat     Long  1/22/20  ...  3/2/20  3/3/20  3/4/20
# Country/Region                             ...
# Afghanistan     33.0000  65.0000        0  ...       1       1       1
# Algeria         28.0339   1.6596        0  ...       3       5      12
# Andorra         42.5063   1.5218        0  ...       1       1       1
# Argentina      -38.4161 -63.6167        0  ...       0       1       1
# Armenia         40.0691  45.0382        0  ...       1       1       1
#
# [5 rows x 45 columns]

# %%
confirmed_by_country.sample(10)
# Out:
#                        Lat       Long  1/22/20  ...  3/2/20  3/3/20  3/4/20
# Country/Region                                  ...
# Portugal          39.39990    -8.2245        0  ...       2       2       5
# Pakistan          30.37530    69.3451        0  ...       4       5       5
# Japan             36.00000   138.0000        2  ...     274     293     331
# Indonesia         -0.78930   113.9213        0  ...       2       2       2
# Switzerland       46.81820     8.2275        0  ...      42      56      90
# Macau             22.16670   113.5500        1  ...      10      10      10
# Others            35.44370   139.6380        0  ...     705     706     706
# Mainland China  1035.61502  3457.8300      547  ...   80026   80151   80271
# Oman              21.00000    57.0000        0  ...       6      12      15
# Italy             43.00000    12.0000        0  ...    2036    2502    3089
#
# [10 rows x 45 columns]

# %%
confirmed_by_country.loc["Mainland China"][2:]
# Out:
# 1/22/20      547.0
# 1/23/20      639.0
# 1/24/20      916.0
# 1/25/20     1399.0
# 1/26/20     2062.0
# 1/27/20     2863.0
# 1/28/20     5494.0
# 1/29/20     6070.0
# 1/30/20     8124.0
# 1/31/20     9783.0
# 2/1/20     11871.0
# 2/2/20     16607.0
# 2/3/20     19693.0
# 2/4/20     23680.0
# 2/5/20     27409.0
# 2/6/20     30553.0
# 2/7/20     34075.0
# 2/8/20     36778.0
# 2/9/20     39790.0
# 2/10/20    42306.0
# 2/11/20    44327.0
# 2/12/20    44699.0
# 2/13/20    59832.0
# 2/14/20    66292.0
# 2/15/20    68347.0
# 2/16/20    70446.0
# 2/17/20    72364.0
# 2/18/20    74139.0
# 2/19/20    74546.0
# 2/20/20    74999.0
# 2/21/20    75472.0
# 2/22/20    76922.0
# 2/23/20    76938.0
# 2/24/20    77152.0
# 2/25/20    77660.0
# 2/26/20    78065.0
# 2/27/20    78498.0
# 2/28/20    78824.0
# 2/29/20    79251.0
# 3/1/20     79826.0
# 3/2/20     80026.0
# 3/3/20     80151.0
# 3/4/20     80271.0
# Name: Mainland China, dtype: float64

# %%
import matplotlib.pyplot as plt

# grafico extremamente apertado
# estamos sendo longe do adequado ao passar uma mensagem errada

plt.figure(figsize=(2,5))
confirmed_by_country.loc["Mainland China"][2:].plot()
plt.title("Casos confirmados em 'Mainland China'")
plt.show()

# %% [markdown]
# Nos últimos 20 dias desses dados, DOBROU os casos confirmados

# %%
# por isso em data visualization é FUNDAMENTAL
# estarmos atentos aos DOIS EIXOS
# esse aqui esta tentando comparar o crescimento do momento inicial ao momento atual

plt.figure(figsize=(10,5))
confirmed_by_country.loc["Mainland China"][2:].plot()
plt.title("Casos confirmados em 'Mainland China'")
plt.show()

# %%
# exemplo ruim de manusear o eixo y
# aqui a mensagem ficou novamente diferente

# esse aqui esta tentando comparar o momento inicial com 1.386bi (populacao da xchina em 2017)
# aqui a mensagem eh novamente completamente diferente
# e pode ser uma mensagem ruim, ate mesmo errada. poderai ser uma doenca grave
# mas ao usarmos o eixo y com a populacao geral, fingimos que ela nao eh grave
# sendo que na realidade ESSE grafico nao POSSUI INFORMACAO NENHUMA sobre a gravidade
# da doenca

# pq? so tem caso confirmado. nao fala letalidade? nao fala incidencia?
# quais sao as provincias infectadas? sao de toda a china? e estou comparando com a
# populacao de toda a china. errado.

plt.figure(figsize=(10,5))
confirmed_by_country.loc["Mainland China"][2:].plot()
plt.title("Gráfico errado. Passa uma mensagem errada, com comparações injustas.")
plt.ylim(0, 1386000000)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Casos novos em 'Mainland China'")
new_cases_mainland_china = confirmed_by_country.loc["Mainland China"][2:].diff().dropna()
new_cases_mainland_china.plot()

# %%
# não faz sentido um gráfico cujo eixo X são categorias não ordenadas com um gráfico delinha
# dá pra ver no gráfico que... não dá para entendê-lo.... por isso vamos tentar em breve
# melhorá-lo

plt.figure(figsize=(10,5))

confirmed_by_country[last_date].plot()
plt.title("Confirmados por país")
# Out:
# Text(0.5, 1.0, 'Confirmados por país')

# %%
plt.figure(figsize=(10,5))

# 99.99% das vezes não devemos usar grafico de pizza e torta
# "se o nome do gráfico tem comida no meio, não use" (boa pratica)

# 1. muitas categorias inviavel
# 2. poucas categorias, a comparacao eh de area!!!


# ah, mas cai no 0.01% que eh pra usar torta/pizza
# não, não caiu. pense novamente. se acredita que sim. pense novamente
# se acrdita que sim, assuma os riscos

confirmed_by_country[last_date].plot(kind='pie')
plt.title("Confirmados por país")
plt.show()

# %%
# melhorando, mas ainda não ideal

plt.figure(figsize=(10,5))

confirmed_by_country[last_date].plot(kind='bar')
plt.title("Confirmados por país")
plt.show()

# %%
# melhor, mas ainda não ideal

plt.figure(figsize=(10,5))

confirmed_by_country[last_date].sort_values(ascending=False).plot(kind='bar')
plt.title("Confirmados por país")
plt.show()

# %%
# opa... chegamos em algo que já ficou útil para destacar o epicentro

plt.figure(figsize=(10,5))

confirmed_by_country[last_date].sort_values(ascending=False)[:10].plot(kind='bar')
plt.title("Confirmados por país")
plt.show()

# %%
# aqui já vira uma comparação entre os países fora do epicentro

plt.figure(figsize=(10,5))

confirmed_by_country[last_date].sort_values(ascending=False)[1:10].plot(kind='bar')
plt.title("Confirmados por país (amostra de 10 países)")
plt.show()

# Lembrando que existe um vicio aqui pois paises que não testaram individuos
# podem sim ter casos ocorrendo mas não confirmados ainda.

# %%
deaths = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv")
recovered = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv")

display(deaths.head())
display(recovered.head())
# Out:
#   Province/State  Country/Region      Lat  ...  3/2/20  3/3/20  3/4/20
# 0          Anhui  Mainland China  31.8257  ...       6       6       6
# 1        Beijing  Mainland China  40.1824  ...       8       8       8
# 2      Chongqing  Mainland China  30.0572  ...       6       6       6
# 3         Fujian  Mainland China  26.0789  ...       1       1       1
# 4          Gansu  Mainland China  36.0611  ...       2       2       2
#
# [5 rows x 47 columns]
#   Province/State  Country/Region      Lat  ...  3/2/20  3/3/20  3/4/20
# 0          Anhui  Mainland China  31.8257  ...     917     936     956
# 1        Beijing  Mainland China  40.1824  ...     282     288     297
# 2      Chongqing  Mainland China  30.0572  ...     469     490     502
# 3         Fujian  Mainland China  26.0789  ...     255     260     270
# 4          Gansu  Mainland China  36.0611  ...      85      86      87
#
# [5 rows x 47 columns]

# %%
def latest_by_country(data):
  return data.groupby("Country/Region").sum().iloc[:,-1]

display(latest_by_country(confirmed).head())
display(latest_by_country(deaths).head())
display(latest_by_country(recovered).head())
# Out:
# Country/Region
# Afghanistan     1
# Algeria        12
# Andorra         1
# Argentina       1
# Armenia         1
# Name: 3/4/20, dtype: int64
# Country/Region
# Afghanistan    0
# Algeria        0
# Andorra        0
# Argentina      0
# Armenia        0
# Name: 3/4/20, dtype: int64
# Country/Region
# Afghanistan    0
# Algeria        0
# Andorra        0
# Argentina      0
# Armenia        0
# Name: 3/4/20, dtype: int64

# %%
informations = [latest_by_country(confirmed), latest_by_country(deaths), latest_by_country(recovered)]
combined = pd.concat(informations, axis=1)
combined.columns = ["confirmed", "deaths", "recovered"]
combined.head()
# Out:
#                 confirmed  deaths  recovered
# Country/Region
# Afghanistan             1       0          0
# Algeria                12       0          0
# Andorra                 1       0          0
# Argentina               1       0          0
# Armenia                 1       0          0

# %%
# taxa de letalidade é expressa em %
# o número de casos letais dentro dos casos que foram letais e não letais

# imagina que existe uma doença que em janeiro de 2020 afetou 100 pessoas
# 5 pessoas morreram (por exemplo). letalidade foi de 5%.
# não digo que ela É de 5% para sempre pq a doença continuou existindo

# conclusão é MUITO dificil de falar de letalidade tentando ser preciso
# durante uma epidemia

# no começo é comum que somente casos graves sejam reportados

# %%
sum_up = combined.sum()
letality_rate_1 = sum_up["deaths"] / sum_up["confirmed"]
letality_rate_2 = sum_up["deaths"] / (sum_up["deaths"] + sum_up["recovered"])
print(letality_rate_1 * 100)
print(letality_rate_2 * 100)
# Out:
# 3.4207981161431396
# 5.978870004593477

# %%
def latest_by_country_at(data, date):
  return data.groupby("Country/Region").sum()[date]


informations = [latest_by_country_at(confirmed, '2/20/20'), latest_by_country_at(deaths, '2/20/20'), latest_by_country_at(recovered, '2/20/20')]
combined_2_20_20 = pd.concat(informations, axis=1)
combined_2_20_20.columns = ["confirmed", "deaths", "recovered"]

sum_up = combined_2_20_20.loc["Mainland China"]
letality_rate_1 = sum_up["deaths"] / sum_up["confirmed"]
letality_rate_2 = sum_up["deaths"] / (sum_up["deaths"] + sum_up["recovered"])
print(letality_rate_1 * 100)
print(letality_rate_2 * 100)
# Out:
# 2.981373084974466
# 11.048522581282736

# %%
display(sum_up)
# Out:
# confirmed    74999
# deaths        2236
# recovered    18002
# Name: Mainland China, dtype: int64

# %%
informations = [latest_by_country_at(confirmed, '2/8/20'), latest_by_country_at(deaths, '2/20/20'), latest_by_country_at(recovered, '2/20/20')]
combined_12 = pd.concat(informations, axis=1)
combined_12.columns = ["confirmed", "deaths", "recovered"]

sum_up = combined_12.loc["Mainland China"]
letality_rate_3 = sum_up["deaths"] / sum_up["confirmed"]
print(letality_rate_3 * 100)
display(sum_up)
# Out:
# 6.079721572679319
# confirmed    36778
# deaths        2236
# recovered    18002
# Name: Mainland China, dtype: int64

# %%
letality_rate_1 = combined["deaths"] / combined["confirmed"] * 100
letality_rate_2 = combined["deaths"] / (combined["recovered"] + combined["deaths"]) * 100
combined["letality_rate_1"] = letality_rate_1
combined["letality_rate_2"] = letality_rate_2
combined.head()
# Out:
#                 confirmed  deaths  recovered  letality_rate_1  letality_rate_2
# Country/Region
# Afghanistan             1       0          0              0.0              NaN
# Algeria                12       0          0              0.0              NaN
# Andorra                 1       0          0              0.0              NaN
# Argentina               1       0          0              0.0              NaN
# Armenia                 1       0          0              0.0              NaN

# %%
combined.sort_values("letality_rate_1", ascending=False).head(10)
# Out:
#                 confirmed  deaths  recovered  letality_rate_1  letality_rate_2
# Country/Region
# Philippines             3       1          1        33.333333        50.000000
# US                    153      11          8         7.189542        57.894737
# San Marino             16       1          0         6.250000       100.000000
# Iraq                   35       2          0         5.714286       100.000000
# Australia              52       2         11         3.846154        15.384615
# Mainland China      80271    2981      49955         3.713670         5.631328
# Italy                3089     107        276         3.463904        27.937337
# Iran                 2922      92        552         3.148528        14.285714
# Taiwan                 42       1         12         2.380952         7.692308
# Thailand               43       1         31         2.325581         3.125000

# %%
# visualização horrenda

combined[["confirmed", "letality_rate_1"]].plot()

# %%
# combined[["confirmed", "letality_rate_1"]].plot(kind='scatter')

# %%
import seaborn as sns

sns.scatterplot(data = combined, x="confirmed", y="letality_rate_1")

# %%
sns.scatterplot(data = combined.query("confirmed > 40 and confirmed < 50000"), x="confirmed", y="letality_rate_1")

# %%
sns.scatterplot(data = combined.query("confirmed > 40"), x="confirmed", y="letality_rate_1")

# %%
sns.scatterplot(data = combined.query("recovered > 40"), x="confirmed", y="letality_rate_2")

# %%
sns.distplot(combined.query("confirmed > 40")["letality_rate_1"], kde=False)

# %%
# grafico nao faz sentido pois so tem 3 pontos ainda

sns.distplot(combined.query("recovered > 40")["letality_rate_2"], kde=False)

# %%
combined.sort_values("letality_rate_1", ascending=False).query("confirmed > 40").head(10)
# Out:
#                 confirmed  deaths  recovered  letality_rate_1  letality_rate_2
# Country/Region
# US                    153      11          8         7.189542        57.894737
# Australia              52       2         11         3.846154        15.384615
# Mainland China      80271    2981      49955         3.713670         5.631328
# Italy                3089     107        276         3.463904        27.937337
# Iran                 2922      92        552         3.148528        14.285714
# Taiwan                 42       1         12         2.380952         7.692308
# Thailand               43       1         31         2.325581         3.125000
# Hong Kong             105       2         37         1.904762         5.128205
# Japan                 331       6         43         1.812689        12.244898
# France                285       4         12         1.403509        25.000000

# %%
combined.sort_values("letality_rate_2", ascending=False).query("recovered > 40").head(10)
# Out:
#                 confirmed  deaths  recovered  letality_rate_1  letality_rate_2
# Country/Region
# South Korea          5621      35         41         0.622665        46.052632
# Italy                3089     107        276         3.463904        27.937337
# Iran                 2922      92        552         3.148528        14.285714
# Japan                 331       6         43         1.812689        12.244898
# Mainland China      80271    2981      49955         3.713670         5.631328
# Singapore             110       0         78         0.000000         0.000000

# %% [markdown]
# # Segunda parte

# %%
confirmed.set_index("Country/Region").loc["Mainland China"].sum().tail()
# Out:
# 2/29/20    79251
# 3/1/20     79826
# 3/2/20     80026
# 3/3/20     80151
# 3/4/20     80271
# dtype: object

# %%
is_mainland = confirmed["Country/Region"] == "Mainland China"
is_mainland.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Country/Region, dtype: bool

# %%
confirmed["is_mainland_china"] = is_mainland
display(confirmed.head())
display(confirmed.tail())
# Out:
#   Province/State  Country/Region      Lat  ...  3/3/20  3/4/20  is_mainland_china
# 0          Anhui  Mainland China  31.8257  ...     990     990               True
# 1        Beijing  Mainland China  40.1824  ...     414     418               True
# 2      Chongqing  Mainland China  30.0572  ...     576     576               True
# 3         Fujian  Mainland China  26.0789  ...     296     296               True
# 4          Gansu  Mainland China  36.0611  ...      91      91               True
#
# [5 rows x 48 columns]
#               Province/State Country/Region  ...  3/4/20  is_mainland_china
# 155                      NaN      Gibraltar  ...       1              False
# 156                      NaN  Liechtenstein  ...       1              False
# 157                      NaN         Poland  ...       1              False
# 158                      NaN        Tunisia  ...       1              False
# 159  Contra Costa County, CA             US  ...       1              False
#
# [5 rows x 48 columns]

# %%
# query só de mainland china
confirmed.query("is_mainland_china")
# Out:
#     Province/State  Country/Region       Lat  ...  3/3/20  3/4/20  is_mainland_china
# 0            Anhui  Mainland China  31.82570  ...     990     990               True
# 1          Beijing  Mainland China  40.18240  ...     414     418               True
# 2        Chongqing  Mainland China  30.05720  ...     576     576               True
# 3           Fujian  Mainland China  26.07890  ...     296     296               True
# 4            Gansu  Mainland China  36.06110  ...      91      91               True
# 5        Guangdong  Mainland China  23.34170  ...    1350    1350               True
# 6          Guangxi  Mainland China  23.82980  ...     252     252               True
# 7          Guizhou  Mainland China  26.81540  ...     146     146               True
# 8           Hainan  Mainland China  19.19590  ...     168     168               True
# 9            Hebei  Mainland China  38.04280  ...     318     318               True
# 10    Heilongjiang  Mainland China  47.86200  ...     480     480               True
# 11           Henan  Mainland China  33.88202  ...    1272    1272               True
# 12           Hubei  Mainland China  30.97560  ...   67217   67332               True
# 13           Hunan  Mainland China  27.61040  ...    1018    1018               True
# 14  Inner Mongolia  Mainland China  44.09350  ...      75      75               True
# 15         Jiangsu  Mainland China  32.97110  ...     631     631               True
# 16         Jiangxi  Mainland China  27.61400  ...     935     935               True
# 17           Jilin  Mainland China  43.66610  ...      93      93               True
# 18        Liaoning  Mainland China  41.29560  ...     125     125               True
# 19         Ningxia  Mainland China  37.26920  ...      74      75               True
# 20         Qinghai  Mainland China  35.74520  ...      18      18               True
# 21         Shaanxi  Mainland China  35.19170  ...     245     245               True
# 22        Shandong  Mainland China  36.34270  ...     758     758               True
# 23        Shanghai  Mainland China  31.20200  ...     338     338               True
# 24          Shanxi  Mainland China  37.57770  ...     133     133               True
# 25         Sichuan  Mainland China  30.61710  ...     538     538               True
# 26         Tianjin  Mainland China  39.30540  ...     136     136               True
# 27           Tibet  Mainland China  31.69270  ...       1       1               True
# 28        Xinjiang  Mainland China  41.11290  ...      76      76               True
# 29          Yunnan  Mainland China  24.97400  ...     174     174               True
# 30        Zhejiang  Mainland China  29.18320  ...    1213    1213               True
#
# [31 rows x 48 columns]

# %%
confirmed.groupby("is_mainland_china").sum()[last_date].plot(kind='pie')

# %%
confirmed.groupby("is_mainland_china").sum()[last_date].plot(kind='bar')

# %% [markdown]
# ## No dia 02/03/2020 mainland china tinha 8 vezes o número de casos que o resto. Mas isso é até injusto pois estamos resumindo as informações e com isso, perdendo elas.
#
# Mas olhar uma fotografia é muito limitado, queremos ver também como anda esse crescimento.

# %%
import numpy as np

confirmed['is_mainland_china_label'] = np.where(confirmed["is_mainland_china"], 'Mainland China', 'Others')
display(confirmed.head())
display(confirmed.tail())
# Out:
#   Province/State  Country/Region  ...  is_mainland_china  is_mainland_china_label
# 0          Anhui  Mainland China  ...               True           Mainland China
# 1        Beijing  Mainland China  ...               True           Mainland China
# 2      Chongqing  Mainland China  ...               True           Mainland China
# 3         Fujian  Mainland China  ...               True           Mainland China
# 4          Gansu  Mainland China  ...               True           Mainland China
#
# [5 rows x 49 columns]
#               Province/State  ... is_mainland_china_label
# 155                      NaN  ...                  Others
# 156                      NaN  ...                  Others
# 157                      NaN  ...                  Others
# 158                      NaN  ...                  Others
# 159  Contra Costa County, CA  ...                  Others
#
# [5 rows x 49 columns]

# %%
confirmed.groupby("is_mainland_china_label").sum()[last_date].plot(kind='bar')
plt.title(f"Casos confirmados acumulados até {last_date}")
plt.show()

# %%
summed = confirmed.groupby("is_mainland_china_label").sum()
summed["delta"] = summed["3/2/20"] - summed["3/1/20"]
summed["delta"].plot(kind='bar')
plt.title(f"Novos casos confirmados em {last_date}")
plt.show()

# %%
summed.T.head()
# Out:
# is_mainland_china_label  Mainland China     Others
# Lat                          1035.61502  4003.2272
# Long                         3457.83000    91.7267
# 1/22/20                       547.00000     8.0000
# 1/23/20                       639.00000    14.0000
# 1/24/20                       916.00000    25.0000

# %%
summed.T[2:-2].plot()
plt.title("Desenvolvimento de casos confirmados com o passar do tempo")
plt.show()

# %%
differences.head()
# Out:
# is_mainland_china_label  Mainland China  Others
# 1/23/20                            92.0     6.0
# 1/24/20                           277.0    11.0
# 1/25/20                           483.0    10.0
# 1/26/20                           663.0    21.0
# 1/27/20                           801.0     8.0

# %%
import datetime
import matplotlib.dates as mdates

differences = summed.T[2:-2].diff().dropna()
ax = differences.plot(figsize=(10,5),
                      title="Casos novos com o decorrer do tempo",
                      grid=True)
plt.legend(["Mainland China", "Outros"])
ax.set_ylabel("# casos")
ax.set_xlabel("O pico ocorreu devido a mudança de abordagem em Hubei onde, por segurança, passou-se a considerar confirmado mesmos casos sem diagnóstico de laboratório.")
plt.show()

# %%
cases = confirmed.groupby("is_mainland_china_label").sum()[last_date].loc["Mainland China"]
estimated_population =  1437525528
incidence_ratio = cases / estimated_population * 100000
incidence_ratio

# conta péssima, e ruim. e errada. pois estou usando uma populacao MUITO maior do que
# deveria estar usando
# Out:
# 5.566927226074276

# %%
un_population = pd.read_csv("https://population.un.org/wpp/Download/Files/1_Indicators%20(Standard)/CSV_FILES/WPP2019_TotalPopulationBySex.csv")
un_population["PopTotal"] = un_population["PopTotal"] * 1000
un_population.head()
# Out:
#    LocID     Location  VarID  ... PopFemale   PopTotal  PopDensity
# 0      4  Afghanistan      2  ...  3652.874  7752117.0      11.874
# 1      4  Afghanistan      2  ...  3705.395  7840151.0      12.009
# 2      4  Afghanistan      2  ...  3761.546  7935996.0      12.156
# 3      4  Afghanistan      2  ...  3821.348  8039684.0      12.315
# 4      4  Afghanistan      2  ...  3884.832  8151316.0      12.486
#
# [5 rows x 10 columns]

# %%
un_population.describe()
# Out:
#                LocID          VarID  ...      PopTotal     PopDensity
# count  280932.000000  280932.000000  ...  2.809320e+05  280932.000000
# mean      703.125062      22.411345  ...  4.128536e+08     426.659040
# std       631.959759      55.972847  ...  1.308911e+09    2418.990784
# min         4.000000       2.000000  ...  1.510000e+02       0.052000
# 25%       300.000000       2.000000  ...  1.240100e+06      34.205250
# 50%       586.000000       5.000000  ...  1.420555e+07      91.590000
# 75%       903.000000       9.000000  ...  1.171661e+08     216.985750
# max      5501.000000     207.000000  ...  2.163274e+10   56025.839000
#
# [8 rows x 8 columns]

# %%
un_population_total = un_population.query("Time==2019")[["Location","PopTotal"]].set_index("Location")
un_population_total.head()
# Out:
#                                    PopTotal
# Location
# Afghanistan                    3.804176e+07
# Africa                         1.308064e+09
# African Group                  1.306321e+09
# African Union                  1.306903e+09
# African Union: Central Africa  1.540137e+08

# %%
combined.join(un_population_total)
# Out:
#                       confirmed  deaths  ...  letality_rate_2    PopTotal
# Afghanistan                   1       0  ...              NaN  38041757.0
# Algeria                      12       0  ...              NaN  43053054.0
# Andorra                       1       0  ...              NaN     77146.0
# Argentina                     1       0  ...              NaN  44780675.0
# Armenia                       1       0  ...              NaN   2957728.0
# ...                         ...     ...  ...              ...         ...
# UK                           85       0  ...         0.000000         NaN
# US                          153      11  ...        57.894737         NaN
# Ukraine                       1       0  ...              NaN  43993643.0
# United Arab Emirates         27       0  ...         0.000000   9770526.0
# Vietnam                      16       0  ...         0.000000         NaN
#
# [86 rows x 6 columns]

# %%
combined.join(un_population_total).sort_values("confirmed", ascending=False).head(20)
# Out:
#                 confirmed  deaths  ...  letality_rate_2     PopTotal
# Mainland China      80271    2981  ...         5.631328          NaN
# South Korea          5621      35  ...        46.052632          NaN
# Italy                3089     107  ...        27.937337   60550092.0
# Iran                 2922      92  ...        14.285714          NaN
# Others                706       6  ...        37.500000          NaN
# Japan                 331       6  ...        12.244898  126860299.0
# France                285       4  ...        25.000000   65129731.0
# Germany               262       0  ...         0.000000   83517046.0
# Spain                 222       2  ...        50.000000   46736782.0
# US                    153      11  ...        57.894737          NaN
# Singapore             110       0  ...         0.000000    5804343.0
# Hong Kong             105       2  ...         5.128205          NaN
# Switzerland            90       0  ...         0.000000    8591361.0
# UK                     85       0  ...         0.000000          NaN
# Kuwait                 56       0  ...              NaN    4207077.0
# Norway                 56       0  ...              NaN    5378859.0
# Australia              52       2  ...        15.384615   25203200.0
# Bahrain                52       0  ...              NaN    1641164.0
# Malaysia               50       0  ...         0.000000   31949789.0
# Thailand               43       1  ...         3.125000   69625581.0
#
# [20 rows x 6 columns]

# %%
un_population_total.index[:5]
# Out:
# Index(['Afghanistan', 'Africa', 'African Group', 'African Union',
#        'African Union: Central Africa'],
#       dtype='object', name='Location')

# %%
def locate(population, country):
  return population.query(f"Location.str.contains('{country}') and Time==2019", engine='python')

locate(un_population, 'Hong K')
# Out:
#        LocID              Location  VarID  ... PopFemale   PopTotal  PopDensity
# 48928    344  China, Hong Kong SAR      2  ...   4017.67  7436157.0    7082.054
#
# [1 rows x 10 columns]

# %%
# vou assumir algumas premissas
# estou assumindo que na UN China = John Hokpins Mainland China

def rename_location(location):
  if location=='China':
    return 'Mainland China'
  if location=='Republic of Korea':
    return 'South Korea'
  if location=='Iran (Islamic Republic of)':
    return 'Iran'
  if location=='China, Hong Kong SAR':
    return 'Hong Kong'
  if location=='United States of America':
    return 'US'
  return location

un_population_total['location_for_who'] = un_population_total.index.map(rename_location)
un_population_total.query("location_for_who=='South Korea'").head()
# Out:
#                      PopTotal location_for_who
# Location
# Republic of Korea  51225321.0      South Korea

# %%
un_population_total = un_population_total.set_index("location_for_who")
un_population_total.head()
# Out:
#                                    PopTotal
# location_for_who
# Afghanistan                    3.804176e+07
# Africa                         1.308064e+09
# African Group                  1.306321e+09
# African Union                  1.306903e+09
# African Union: Central Africa  1.540137e+08

# %%
combined_expanded = combined.join(un_population_total).sort_values("confirmed", ascending=False).dropna()
combined_expanded.head(10)
# Out:
#                 confirmed  deaths  ...  letality_rate_2      PopTotal
# Mainland China      80271    2981  ...         5.631328  1.433784e+09
# South Korea          5621      35  ...        46.052632  5.122532e+07
# Italy                3089     107  ...        27.937337  6.055009e+07
# Iran                 2922      92  ...        14.285714  8.291389e+07
# Japan                 331       6  ...        12.244898  1.268603e+08
# France                285       4  ...        25.000000  6.512973e+07
# Germany               262       0  ...         0.000000  8.351705e+07
# Spain                 222       2  ...        50.000000  4.673678e+07
# US                    153      11  ...        57.894737  3.290649e+08
# Singapore             110       0  ...         0.000000  5.804343e+06
#
# [10 rows x 6 columns]

# %%
# O cálculo de incidencia aqui está errado, pois assumi que a população em risco de Mainland China é todo mundo
# mas até agora 83% dos casos estão em Hubei
# Durante esse momento da epidemia é injusto com a localização (Mainland China) considerar essa incidência.

combined_expanded['incidence_ratio'] = combined_expanded['confirmed'] / combined_expanded['PopTotal'] * 100000
combined_expanded['mortality_rate'] = combined_expanded['deaths'] / combined_expanded['PopTotal'] * 100000
combined_expanded.head(10)
# Out:
#                 confirmed  deaths  ...  incidence_ratio  mortality_rate
# Mainland China      80271    2981  ...         5.598543        0.207911
# South Korea          5621      35  ...        10.973089        0.068326
# Italy                3089     107  ...         5.101561        0.176713
# Iran                 2922      92  ...         3.524138        0.110958
# Japan                 331       6  ...         0.260917        0.004730
# France                285       4  ...         0.437588        0.006142
# Germany               262       0  ...         0.313708        0.000000
# Spain                 222       2  ...         0.475001        0.004279
# US                    153      11  ...         0.046495        0.003343
# Singapore             110       0  ...         1.895133        0.000000
#
# [10 rows x 8 columns]

# %% [markdown]
# Penso em comparar com outro virus, como Influenza, em outro pais, como Brasil, em outro estado,
# como Rio Grande do Sul, em outro período de 2019, em outro tamanho de período de 1 ano inteiro versus 2 meses.
#
# Totalmente diferente, qual a chance da comparação ser justa e honesta?
#
# Fonte: https://www.cevs.rs.gov.br/informativos-epidemiologicos-2019
#
#
# > O coeficiente de incidência entre os SRAG, está em 3,88/100.000 habitantes, o coeficiente de mortalidade (CM) está em 0,61/100.000 habitantes, enquanto que o CM nacional, na SE 46 foi de 0,50/100.000 habitantes. A letalidade no Estado está em 15,8%.
#
# Parece que, dado o coeficiente de incidencia nos paises afetados pelo coronavirus até então, e somente o tempo de 2 meses, além da curva de crescimento de casos novos na China e fora da China, parece que existe ainda um triste potencial alto de um coeficiente de incidência mais alto que Influenza no relatório analisado.
#
# Mesmo que comparemos com o CDB Burden Influenza, ou outros relatorios é muito dificil pois estamos no começo da epidemia. Além disso, são muitas variáveis e métricas distintas.

# %%
confirmed.sort_values(last_date, ascending=False).head()
# Out:
#    Province/State  Country/Region  ...  is_mainland_china  is_mainland_china_label
# 12          Hubei  Mainland China  ...               True           Mainland China
# 33            NaN     South Korea  ...              False                   Others
# 59            NaN           Italy  ...              False                   Others
# 74            NaN            Iran  ...              False                   Others
# 5       Guangdong  Mainland China  ...               True           Mainland China
#
# [5 rows x 49 columns]

# %%
# https://en.wikipedia.org/wiki/Hubei
# hubei population

hubei_population = 59020000
confirmed_cases = confirmed.set_index("Province/State").loc["Hubei"][last_date]
death_cases = deaths.set_index("Province/State").loc["Hubei"][last_date]
recovered_cases = recovered.set_index("Province/State").loc["Hubei"][last_date]

letality_rate_1 = death_cases / confirmed_cases * 100
letality_rate_2 = death_cases / (death_cases + recovered_cases) * 100
print(f"Letality rate 1: {letality_rate_1}%")
print(f"Letality rate 2: {letality_rate_2}%")
# Out:
# Letality rate 1: 4.177160484628109%
# Letality rate 2: 7.629909900100716%

# %%
# nos estados unidos de acordo com burden report de influenza 2018-2019 estimativa não final
letality_rate_hospitalization = 34157 / 490561 * 100

print(f"Letality rate hospitalização EUA influenza 2018-2019: {letality_rate_hospitalization}%")
# Out:
# Letality rate hospitalização EUA influenza 2018-2019: 6.962844579980879%

# %%
# nos estados unidos de acordo com burden report de influenza 2018-2019 estimativa não final
letality_rate_medical_visit = 34157 / 16520350 * 100

print(f"Letality rate visita médica EUA influenza 2018-2019: {letality_rate_medical_visit}%")
# Out:
# Letality rate visita médica EUA influenza 2018-2019: 0.20675712076317995%

# %%
# nos estados unidos de acordo com burden report de influenza 2018-2019 estimativa não final
letality_rate_symptomatic = 34157 / 35520883 * 100

print(f"Letality rate sintomáticos EUA influenza 2018-2019: {letality_rate_symptomatic}%")
# Out:
# Letality rate sintomáticos EUA influenza 2018-2019: 0.09616033475293956%

# %%
incidence_ratio = confirmed_cases / hubei_population * 100000
mortality_rate = death_cases / hubei_population * 100000

print(f"Coeficiente de incidencia em Hubei {incidence_ratio}")
print(f"Coeficiente de mortalidade em Hubei {mortality_rate}")
# Out:
# Coeficiente de incidencia em Hubei 113.69535750593019
# Coeficiente de mortalidade em Hubei 4.749237546594375

# %%
# estados unidos, mesmo relatorio de burden, coeficiente de incidencia

incidence_ratio = 35520883 / 329450000 * 100000
mortality_rate = 34157 / 329450000 * 100000

print(f"Coeficiente de incidencia de influenza 2018-2019 em EUA  {incidence_ratio}")
print(f"Coeficiente de mortalidade de influenza 2018-2019 em EUA {mortality_rate}")
# Out:
# Coeficiente de incidencia de influenza 2018-2019 em EUA  10781.873728942177
# Coeficiente de mortalidade de influenza 2018-2019 em EUA 10.367885870390044

# %% [markdown]
# É muito ruim e muito difícil fazer comparação com períodos de tempo diferentes (2 meses / 12 meses). Você quer extrapolar simplesmente e multiplicar por 6? 24 a mortalidade. Mas extrapolar com esse tipo de crescimento pode ser muito irreal. Então infelizmente tem que ir por estimativas.... estatística.

# %%
grouped_per_day = pd.DataFrame([confirmed.sum()[2:-1],recovered.sum()[2:], deaths.sum()[2:]],
            index=["confirmed", "recovered", "deaths"]).T
grouped_per_day.head()
# Out:
#          confirmed  recovered  deaths
# 1/22/20      555.0       28.0    17.0
# 1/23/20      653.0       30.0    18.0
# 1/24/20      941.0       36.0    26.0
# 1/25/20     1434.0       39.0    42.0
# 1/26/20     2118.0       52.0    56.0

# %%
grouped_per_day["letality_rate_1"] = grouped_per_day["deaths"]/ grouped_per_day["confirmed"] * 100
grouped_per_day["letality_rate_2"] = grouped_per_day["deaths"] / (grouped_per_day["deaths"] + grouped_per_day["recovered"]) * 100
grouped_per_day.head()
# Out:
#          confirmed  recovered  deaths  letality_rate_1  letality_rate_2
# 1/22/20      555.0       28.0    17.0         3.063063        37.777778
# 1/23/20      653.0       30.0    18.0         2.756508        37.500000
# 1/24/20      941.0       36.0    26.0         2.763018        41.935484
# 1/25/20     1434.0       39.0    42.0         2.928870        51.851852
# 1/26/20     2118.0       52.0    56.0         2.644004        51.851852

# %%
fig = plt.figure(figsize=(10,5))
grouped_per_day["letality_rate_1"].plot()
ax = grouped_per_day["letality_rate_2"].plot()
plt.legend(['Mortes por casos confirmados ("otimista")', 'Mortes por casos recuperados ou óbitos ("pessimista")'])
plt.title("Taxa de letalidade do COVID-19 (evolução acumulada)", pad=10)
plt.grid(linestyle='-')
ax.set_ylabel("letalidade %")
ax.set_xlabel("Fonte Johns Hopkins CSSE / Gráfico e Collab www.alura.com.br", labelpad=10)
plt.show()

# %%
grouped_per_day["letality_rate_2"].plot()
plt.title("Mortes por casos recuperados ou mortos no mundo todo")
plt.show()

# %%
grouped_per_day["letality_rate_1"].plot()
plt.title("Mortes por casos confirmados no mundo todo")
plt.show()
